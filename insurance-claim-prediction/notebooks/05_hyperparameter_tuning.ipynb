# %% [markdown]
# ### 6.2.1. HYPERPARAMETER TUNING (DECISION TREE)

# %%
params_dt={ 'criterion': ['gini', 'entropy'],
    'max_depth': [15, 25, 35, None],
    'min_samples_split': [5, 10, 20],
    'min_samples_leaf': [2, 4, 6, 8],
    'max_features': ['sqrt', 'log2']  }

# %%
dt_hpt_model=DecisionTreeClassifier()

# %%
dt_cv=RandomizedSearchCV(estimator=dt_hpt_model,
                   param_distributions=params_dt,
                   scoring='accuracy',
                    n_iter=15,
                   n_jobs=-1,
                   verbose=3,
                   cv=3
                  )

# %%
dt_cv.fit(pca_x_train,y_train_smote)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# RandomizedSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_iter=15,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [15, 25, 35, None],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [2, 4, 6, 8],
#                                         'min_samples_split': [5, 10, 20]},
#                    scoring='accuracy', verbose=3)

# %%
print(f'Best_Params:{dt_cv.best_params_}')
# Out:
# Best_Params:{'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 35, 'criterion': 'entropy'}

# %%
best_dt = dt_cv.best_estimator_
dt_hp_pred = best_dt.predict(pca_x_test)
dt_hp_accuracy = accuracy_score(y_test, dt_hp_pred)
print(f"Test Accuracy: {dt_hp_accuracy}")
# Out:
# Test Accuracy: 0.8287425552111422

# %%
dt_cr=classification_report(y_test,dt_hp_pred)
print(dt_cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.85      0.91    114658
#            1       0.04      0.16      0.06      4385
#
#     accuracy                           0.83    119043
#    macro avg       0.50      0.51      0.48    119043
# weighted avg       0.93      0.83      0.87    119043

# %%
dt_cm=confusion_matrix(y_test,dt_hp_pred)
print(dt_cm)
# Out:
# [[97966 16692]
#  [ 3695   690]]

# %% [markdown]
# ### 6.3.1. HYPERPARAMETER TUNING (RANDOM FOREST)

# %%
params_rf = {
    'n_estimators': [50,70],
    'max_depth': [15, 25, 35],
    'min_samples_split': [5, 10],
    'min_samples_leaf': [2, 4],
    'max_features': ['sqrt'],
    'bootstrap': [True],
}

# %%
rf_hpt_model=RandomForestClassifier()
RF_CV = RandomizedSearchCV(
    estimator=rf_hpt_model,
    param_distributions=params_rf,
    n_iter=10,
    cv=3,
    scoring='accuracy',
    verbose=3,
    n_jobs=4,

)

# %%
RF_CV.fit(pca_x_train,y_train_smote)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=4,
#                    param_distributions={'bootstrap': [True],
#                                         'max_depth': [15, 25, 35],
#                                         'max_features': ['sqrt'],
#                                         'min_samples_leaf': [2, 4],
#                                         'min_samples_split': [5, 10],
#                                         'n_estimators': [50, 70]},
#                    scoring='accuracy', verbose=3)

# %%
print(f'Best_Params:{RF_CV.best_params_}')
# Out:
# Best_Params:{'n_estimators': 50, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 35, 'bootstrap': True}

# %%
best_rf = RF_CV.best_estimator_
rf_hp_pred = best_rf.predict(pca_x_test)
rf_hp_accuracy = accuracy_score(y_test, rf_hp_pred)
print(f"Test Accuracy: {rf_hp_accuracy}")
# Out:
# Test Accuracy: 0.916971178481725

# %%
rf_cr=classification_report(y_test,rf_hp_pred)
print(rf_cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96    114658
#            1       0.04      0.06      0.05      4385
#
#     accuracy                           0.92    119043
#    macro avg       0.50      0.50      0.50    119043
# weighted avg       0.93      0.92      0.92    119043

# %%
rf_cm=confusion_matrix(y_test,rf_hp_pred)
print(rf_cm)
# Out:
# [[108914   5744]
#  [  4140    245]]

# %% [markdown]
# ### 6.4.1. HYPERPARAMETER TUNING (GRADIENT BOOSTING)

# %%
gbc = GradientBoostingClassifier()
param_grid_gb = {
    'n_estimators': [50, 70],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5],
    'min_samples_split': [5, 10],
    'min_samples_leaf': [2, 4],
    'subsample': [0.8]
}

# %%
grid_search_gb = RandomizedSearchCV(
    estimator=gbc,
    param_distributions=param_grid_gb,
    n_iter=10,
    cv=3,
    scoring='accuracy',
    n_jobs=-1,
    verbose=3
)

# %%
grid_search_gb.fit(pca_x_train, y_train_smote)
print("Best Parameters:", grid_search_gb.best_params_)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best Parameters: {'subsample': 0.8, 'n_estimators': 70, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_depth': 5, 'learning_rate': 0.1}

# %%
best_gb = grid_search_gb.best_estimator_
gb_hp_pred = grid_search_gb.predict(pca_x_test)
gb_hp_accuracy = accuracy_score(y_test, gb_hp_pred)
print(f"Test Accuracy: {gb_hp_accuracy:.4f}")
# Out:
# Test Accuracy: 0.8440

# %%
print(classification_report(y_test, gb_hp_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91    114658
#            1       0.04      0.14      0.06      4385
#
#     accuracy                           0.84    119043
#    macro avg       0.50      0.51      0.49    119043
# weighted avg       0.93      0.84      0.88    119043

# %%
print(confusion_matrix(y_test, gb_hp_pred))
# Out:
# [[99834 14824]
#  [ 3751   634]]

# %% [markdown]
# ### 6.5.1. HYPERPARAMETER TUNING (KNN)

# %%
param_grid_knn = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}
knn = KNeighborsClassifier()

# %%
knn_cv = RandomizedSearchCV(
    estimator=knn,
    param_distributions=param_grid_knn,
    n_iter=10,
    cv=3,
    scoring='accuracy',
    verbose=3,
    n_jobs=-1
)
knn_cv.fit(pca_x_train, y_train_smote)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3, estimator=KNeighborsClassifier(), n_jobs=-1,
#                    param_distributions={'metric': ['euclidean', 'manhattan'],
#                                         'n_neighbors': [3, 5, 7, 9],
#                                         'weights': ['uniform', 'distance']},
#                    scoring='accuracy', verbose=3)

# %%
print(f"Best Parameters: {knn_cv.best_params_}")
# Out:
# Best Parameters: {'weights': 'uniform', 'n_neighbors': 3, 'metric': 'manhattan'}

# %%
best_knn = knn_cv.best_estimator_
knn_hp_pred = best_knn.predict(pca_x_test)
knn_hp_accuracy = accuracy_score(y_test, knn_hp_pred)
print(f"Test Accuracy: {knn_hp_accuracy:.4f}")
# Out:
# Test Accuracy: 0.7792

# %%
knn_cr=classification_report(y_test,knn_hp_pred)
print(knn_cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.80      0.87    114658
#            1       0.04      0.23      0.07      4385
#
#     accuracy                           0.78    119043
#    macro avg       0.50      0.51      0.47    119043
# weighted avg       0.93      0.78      0.85    119043

# %%
knn_cm=confusion_matrix(y_test,knn_hp_pred)
print(knn_cm)
# Out:
# [[91763 22895]
#  [ 3387   998]]
