# %% [markdown]
# # 4. DATAPREPROCESSING

# %% [markdown]
# ## 4.1. HANDLING NULL VALUES

# %%
Data.isnull().sum()
# Out:
# target            0
# ps_ind_01         0
# ps_ind_02_cat     0
# ps_ind_03         0
# ps_ind_04_cat     0
# ps_ind_05_cat     0
# ps_ind_06_bin     0
# ps_ind_07_bin     0
# ps_ind_08_bin     0
# ps_ind_09_bin     0
# ps_ind_10_bin     0
# ps_ind_11_bin     0
# ps_ind_12_bin     0
# ps_ind_13_bin     0
# ps_ind_14         0
# ps_ind_15         0
# ps_ind_16_bin     0
# ps_ind_17_bin     0
# ps_ind_18_bin     0
# ps_reg_01         0
# ps_reg_02         0
# ps_reg_03         0
# ps_car_01_cat     0
# ps_car_02_cat     0
# ps_car_03_cat     0
# ps_car_04_cat     0
# ps_car_05_cat     0
# ps_car_06_cat     0
# ps_car_07_cat     0
# ps_car_08_cat     0
# ps_car_09_cat     0
# ps_car_10_cat     0
# ps_car_11_cat     0
# ps_car_11         0
# ps_car_12         0
# ps_car_13         0
# ps_car_14         0
# ps_car_15         0
# ps_calc_01        0
# ps_calc_02        0
# ps_calc_03        0
# ps_calc_04        0
# ps_calc_05        0
# ps_calc_06        0
# ps_calc_07        0
# ...

# %% [markdown]
# ## 4.2. HANDLING DUPLICATES

# %%
Data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 4.3. CORRELATION

# %%
# Check for correlation to avoid multicollinearity

plt.figure(figsize=(80,80))
sns.heatmap(data=Data.loc[:,Data.columns != "target"].corr(),annot=True, annot_kws={"size": 18})
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
plt.show()

# %%
Data.loc[:,Data.columns != "target"].corr()
# Out:
#                 ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  \
# ps_ind_01        1.000000      -0.001793   0.223408       0.066645
# ps_ind_02_cat   -0.001793       1.000000  -0.061189       0.147110
# ps_ind_03        0.223408      -0.061189   1.000000      -0.095856
# ps_ind_04_cat    0.066645       0.147110  -0.095856       1.000000
# ps_ind_05_cat    0.014823      -0.014860   0.053250       0.013053
# ps_ind_06_bin   -0.277458      -0.125653  -0.045158      -0.297737
# ps_ind_07_bin    0.005700       0.016398  -0.060368       0.304949
# ps_ind_08_bin    0.188583       0.030945   0.014037       0.044978
# ps_ind_09_bin    0.162800       0.110076   0.111306      -0.011442
# ps_ind_10_bin    0.001847      -0.000744   0.006865       0.000789
# ps_ind_11_bin   -0.016727       0.000772  -0.003986       0.001018
# ps_ind_12_bin   -0.023406      -0.004616   0.001698      -0.001217
# ps_ind_13_bin   -0.008776      -0.001187   0.003929      -0.000893
# ...

# %% [markdown]
# ## 4.4. CHECKING CLASS IMBALANCE

# %%
Data["target"].value_counts()
# Out:
# target
# 0    573518
# 1     21694
# Name: count, dtype: int64

# %%
max_class = Data["target"].value_counts().max()
min_class = Data["target"].value_counts().min()
imbalance_ratio = max_class / min_class

print(f"Imbalance Ratio: {imbalance_ratio}")
# Out:
# Imbalance Ratio: 26.43671061122891
