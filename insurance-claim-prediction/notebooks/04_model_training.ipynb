# %% [markdown]
# # 6. MODEL CREATION

# %% [markdown]
# ## 6.1. LOGISTIC REGRESSION

# %%
log_model=LogisticRegression()
log_model.fit(pca_x_train,y_train_smote)
y_pred=log_model.predict(pca_x_test)
print(f' log_accuracy_score :{accuracy_score(y_test,y_pred)}\n')

print(f' log_classification_report :{classification_report(y_test,y_pred)}')
log_accuracy=accuracy_score(y_test,y_pred)
print(log_accuracy)
# Out:
#  log_accuracy_score :0.7870349369555538
#
#  log_classification_report :              precision    recall  f1-score   support
#
#            0       0.96      0.81      0.88    114658
#            1       0.04      0.22      0.07      4385
#
#     accuracy                           0.79    119043
#    macro avg       0.50      0.51      0.48    119043
# weighted avg       0.93      0.79      0.85    119043
#
# 0.7870349369555538

# %% [markdown]
# ## 6.2. DECISION TREE CLASSIFIER

# %%
dt_model=DecisionTreeClassifier()
dt_model.fit(pca_x_train,y_train_smote)
y_preddt=dt_model.predict(pca_x_test)
print(f' dt_accuracy_score :{accuracy_score(y_test,y_preddt)}\n')
print(f' dt_confusion_matrix :{confusion_matrix(y_test,y_preddt)}\n')
print(f' dt_classification_report :{classification_report(y_test,y_preddt)}')
detr_acc = accuracy_score(y_test,y_preddt)
# Out:
#  dt_accuracy_score :0.8076073351646044
#
#  dt_confusion_matrix :[[95347 19311]
#  [ 3592   793]]
#
#  dt_classification_report :              precision    recall  f1-score   support
#
#            0       0.96      0.83      0.89    114658
#            1       0.04      0.18      0.06      4385
#
#     accuracy                           0.81    119043
#    macro avg       0.50      0.51      0.48    119043
# weighted avg       0.93      0.81      0.86    119043

# %% [markdown]
# ## 6.3. RANDOM FOREST CLASSIFIER

# %%
rf_model=RandomForestClassifier()
rf_model.fit(pca_x_train,y_train_smote)
y_preddr=rf_model.predict(pca_x_test)
print(f' rf_accuracy_score :{accuracy_score(y_test,y_preddr)}\n')
print(f' rf_confusion_matrix :{confusion_matrix(y_test,y_preddr)}\n')
print(f' rf_classification_report :{classification_report(y_test,y_preddr)}')
ranfo_acc = accuracy_score(y_test,y_preddr)
# Out:
#  rf_accuracy_score :0.9240274522651479
#
#  rf_confusion_matrix :[[109791   4867]
#  [  4177    208]]
#
#  rf_classification_report :              precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96    114658
#            1       0.04      0.05      0.04      4385
#
#     accuracy                           0.92    119043
#    macro avg       0.50      0.50      0.50    119043
# weighted avg       0.93      0.92      0.93    119043

# %% [markdown]
# ## 6.4. GRADIENT BOOSTING CLASSIFIER

# %%
gb_model=GradientBoostingClassifier()
gb_model.fit(pca_x_train,y_train_smote)
y_predg=gb_model.predict(pca_x_test)
print(f' gb_accuracy_score :{accuracy_score(y_test,y_predg)}\n')
print(f' gb_confusion_matrix :{confusion_matrix(y_test,y_predg)}\n')
print(f' gb_classification_report :{classification_report(y_test,y_predg)}')
gradb_acc = accuracy_score(y_test,y_predg)
# Out:
#  gb_accuracy_score :0.8402594020648001
#
#  gb_confusion_matrix :[[99390 15268]
#  [ 3748   637]]
#
#  gb_classification_report :              precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91    114658
#            1       0.04      0.15      0.06      4385
#
#     accuracy                           0.84    119043
#    macro avg       0.50      0.51      0.49    119043
# weighted avg       0.93      0.84      0.88    119043

# %% [markdown]
# ## 6.5. K-NEIGHBORS CLASSIFIER (KNN)

# %%
knn_model=KNeighborsClassifier()
knn_model.fit(pca_x_train,y_train_smote)
y_predk=knn_model.predict(pca_x_test)
print(f' knn_accuracy_score :{accuracy_score(y_test,y_predk)}\n')
print(f' knn_confusion_matrix :{confusion_matrix(y_test,y_predk)}\n')
print(f' knn_classification_report :{classification_report(y_test,y_predk)}')
knnei_acc = accuracy_score(y_test,y_predk)
# Out:
#  knn_accuracy_score :0.7363221693001688
#
#  knn_confusion_matrix :[[86476 28182]
#  [ 3207  1178]]
#
#  knn_classification_report :              precision    recall  f1-score   support
#
#            0       0.96      0.75      0.85    114658
#            1       0.04      0.27      0.07      4385
#
#     accuracy                           0.74    119043
#    macro avg       0.50      0.51      0.46    119043
# weighted avg       0.93      0.74      0.82    119043

# %% [markdown]
# ## 6.6. ARTIFICIAL NEURAL NETWORKS (ANN)

# %%
ann_model=MLPClassifier()
ann_model.fit(pca_x_train,y_train_smote)
y_predan=ann_model.predict(pca_x_test)
print(f' ann_accuracy_score :{accuracy_score(y_test,y_predan)}\n')
print(f' ann_confusion_matrix :{confusion_matrix(y_test,y_predan)}\n')
print(f' ann_classification_report :{classification_report(y_test,y_predan)}')
ann_accuracy=accuracy_score(y_test,y_predan)
# Out:
#  ann_accuracy_score :0.8643095352099661
#
#  ann_confusion_matrix :[[102299  12359]
#  [  3794    591]]
#
#  ann_classification_report :              precision    recall  f1-score   support
#
#            0       0.96      0.89      0.93    114658
#            1       0.05      0.13      0.07      4385
#
#     accuracy                           0.86    119043
#    macro avg       0.50      0.51      0.50    119043
# weighted avg       0.93      0.86      0.90    119043
